# %% [markdown]
# # Reading Data

# %%
#pip install pandas

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth',100)
data = pd.read_csv('24k.csv')
print(data)
# Out:
#                                                                        comment
# 0           aa judges ni change cheysey daka programme chuddam manestey better
# 1                        Aa kamma koritala gaadu kavalni chetta cinema teesadu
# 2      Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# 3                  Aa Kick ye veeru yenni sarlu chusinaa chudali anipisthundhi
# 4                                            Aa kothi dancer ni pampandi mundu
# ...                                                                        ...
# 23852                                                     Jelo pettandi vadini
# 23853     Anil garu\nMiru rithu antunaru raithula kastalu miku thelusa ra sale
# 23854               Satish Kumar ni kotandi brother vadu pastor useless fellow
# 23855                                                       Vadu chillara gadu
# 23856                           Bokkara ne abivruddi soniyamma Neku chepindara
#
# [23857 rows x 1 columns]

# %% [markdown]
# # Preprocessing

# %%
import string
def remove_punctuation(txt):
    txt_nopunct="".join([word for word in txt if word not in string.punctuation])
    return txt_nopunct
data['msg_clean']=data['comment'].apply(lambda x: remove_punctuation(x))
print(data)
# Out:
#                                                                        comment  \
# 0           aa judges ni change cheysey daka programme chuddam manestey better
# 1                        Aa kamma koritala gaadu kavalni chetta cinema teesadu
# 2      Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# 3                  Aa Kick ye veeru yenni sarlu chusinaa chudali anipisthundhi
# 4                                            Aa kothi dancer ni pampandi mundu
# ...                                                                        ...
# 23852                                                     Jelo pettandi vadini
# 23853     Anil garu\nMiru rithu antunaru raithula kastalu miku thelusa ra sale
# 23854               Satish Kumar ni kotandi brother vadu pastor useless fellow
# 23855                                                       Vadu chillara gadu
# 23856                           Bokkara ne abivruddi soniyamma Neku chepindara
#
#                                                                      msg_clean
# 0           aa judges ni change cheysey daka programme chuddam manestey better
# 1                        Aa kamma koritala gaadu kavalni chetta cinema teesadu
# 2      Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# 3                  Aa Kick ye veeru yenni sarlu chusinaa chudali anipisthundhi
# 4                                            Aa kothi dancer ni pampandi mundu
# ...                                                                        ...
# 23852                                                     Jelo pettandi vadini
# 23853     Anil garu\nMiru rithu antunaru raithula kastalu miku thelusa ra sale
# 23854               Satish Kumar ni kotandi brother vadu pastor useless fellow
# 23855                                                       Vadu chillara gadu
# 23856                           Bokkara ne abivruddi soniyamma Neku chepindara
#
# [23857 rows x 2 columns]

# %%
#pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nagajyothi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
def tokenize(txt):
    tokens=re.split('\W+',txt)
    return tokens
data['tokenized']=data['msg_clean'].apply(lambda x: tokenize(x.lower()))
print(data.head())
# Out:
#                                                                    comment  \
# 0       aa judges ni change cheysey daka programme chuddam manestey better
# 1                    Aa kamma koritala gaadu kavalni chetta cinema teesadu
# 2  Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# 3              Aa Kick ye veeru yenni sarlu chusinaa chudali anipisthundhi
# 4                                        Aa kothi dancer ni pampandi mundu
#
#                                                                  msg_clean  \
# 0       aa judges ni change cheysey daka programme chuddam manestey better
# 1                    Aa kamma koritala gaadu kavalni chetta cinema teesadu
# 2  Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# 3              Aa Kick ye veeru yenni sarlu chusinaa chudali anipisthundhi
# 4                                        Aa kothi dancer ni pampandi mundu
#
#                                                                             tokenized
# 0       [aa, judges, ni, change, cheysey, daka, programme, chuddam, manestey, better]
# 1                      [aa, kamma, koritala, gaadu, kavalni, chetta, cinema, teesadu]
# 2  [aa, karthika, deepam, timing, marchesthe, intlo, chala, mandi, matches, chudachu]
# 3               [aa, kick, ye, veeru, yenni, sarlu, chusinaa, chudali, anipisthundhi]
# 4                                            [aa, kothi, dancer, ni, pampandi, mundu]
# <>:3: DeprecationWarning: invalid escape sequence \W
# <>:3: DeprecationWarning: invalid escape sequence \W
# C:\Users\Nagajyothi\AppData\Local\Temp\ipykernel_22632\3778880445.py:3: DeprecationWarning: invalid escape sequence \W
#   tokens=re.split('\W+',txt)

# %%
eng_stopwords = set(stopwords.words("english"))

tel_stopwords = ["chetha","cheta","valana","gurchi","goorchi","koraku","andhu","ori","oree","ooyee","oyee","ooyi","oosee","osee","oosi","osi","ee","e","aa","a","nunchi","kudaa","kuda","kooda","koodaa","mi","mii","me","mee","na","naa","un","oka","undhi","vundhi","vundi","vundhe","vunde","unde","undhe","undi","kani","kaani","kanee","idhi","ide","kosam","tha","ayithe","aithe","ayitha",
              "aitha","aite","ayite","ma","ante","antaa","anta","chala","ila","ilaa","ela","vunde","unde","vunda","unda","ane","anaa","vari","vaari","meeru","meru","miru","ela","ala","peru","veeti","ippu","eppu","gurinchi","vara","pun","andhu","paatu","patu","ann","pa","dhee","oo","ani","ki","ku","la","em","inka","enka","ni","ye","ra","du","1","2","3","4","5","6","7","8","9","0",
              "lo","ga","u","ne","tho","anna","adi","ra","ur","iam","im","anna","bro","sis","plz","asalu","antha","nee","andi","enti","mari","ledhu","lu","chesi","kadha","ka","valla","vallu","anni","adhi","malli","ke","ekkada","entha","dont","didnt","kadu","unte","appudu","enni","Enduku","emi","meku","unna","okka","chusi","chesa","edi","raa","meeku","vere",
                 "niku","katti","chusina","idi","laga","epudu","mundu","edhi","leda","entra","cant","anti","chepu","neku","naaku","elanti","sari","ippudu","sarlu","nundi","baaga","rey","intha","evaru","kanna","meda","ilanti","gari","gadu","sir","video","please","super","good","like","videos","one","thank","best","garu","naku","hi","much","use","thanks","nice","also","pls","kada","mana","cheyandi","channel","telugu",
                 "rishi","great","brother","cheppandi","reply","try","ledu","know","baga","really","r","vasu","keep","first","manchi","want","next","tell","nuvvu","get","madam","give","see","many","number","k","us","change","every","tq","better","name","think","last","th","reddy","take","endhuku","comment","cheyali","maa","full" "need","go","chesina","ok","n","babu","manam","eppudu","even","chesaru","hai","amazing","vedio","correct",
                 "always","lot","sister","memu","say","maku","cheppandi","may","doubt","kavali","would","well","ekkuva","going","ha","nd","cheyyandi","yes","come","chepparu","cheppu","cheste","nuvu","gaa","meeda","got","made","chaala","useful","chesanu","bad","already","two","hello","avi","never","chese","type","andharu","konchem","said","plzz","ah","untundi","chey","pani","kadhu","nv","without","annaya","miku","akkada","aina","varaku","thing","konchem","g","true","konni","matram","mm","let",
                 "chinna","de","hii","vallaki","andhuke","nu","ade","neeku","okasari","se","gaaru","giving","per","chestaru","vasthundi","daggara","madni","add","c","vunna","cheyyali","petti","vachindi","still","vunte","lekunda","cheyadam","undali","endhuku","untundhi","sorry","antaru","annaru","tried","sure","make","enduku","new","bagundi","daily","roju","day","ami","ayina","yela","anthe","leka","emo","anthe","gani","akka","amma","nenu",'news',"broo"]

special_chars=["Ã"," ","","¢","ï","à",'ù',"ð","Ã¢?Â¦","?","¦",'~', ':', "'", '+', '[', '\\', '@', '^', '{', '%', '(', '-', '"', '*', '|', ',', '&', '<', '`', '}', '.', '_', '=', ']', '!', '>', ';', '?', '#', '$', ')', '/']

# %%
def dele_stopwords_english(txt):
    txt_rsw=[word for word in txt if word not in eng_stopwords]
    return txt_rsw
def dele_stopwords_telugu(txt):
    txt_rsw=[word for word in txt if word not in tel_stopwords]
    return txt_rsw
def del_special_chars(txt):
  txt_rsw=[word for word in txt if word not in special_chars]
  return txt_rsw
temp=data['english']=data['tokenized'].apply(lambda x: dele_stopwords_english(x))
data['telugu']=data['english'].apply(lambda x: dele_stopwords_telugu(x))
data['telugu']=data['telugu'].apply(lambda x: del_special_chars(x))

# %%
from nltk import FreqDist
all_words = []
[all_words.extend(text) for text in data['telugu']]
fdist = FreqDist(all_words)
print("Total unique words in corpus: ", len(fdist))
# Out:
# Total unique words in corpus:  29555

# %%
k = 1000
top_k_words = fdist.most_common(k)
print(top_k_words[:1000])
# Out:
# [('movie', 661), ('england', 472), ('match', 450), ('love', 415), ('phone', 392), ('world', 368), ('mobile', 356), ('episode', 307), ('cup', 283), ('cricket', 255), ('time', 250), ('dhoni', 249), ('story', 246), ('madhu', 243), ('kathi', 238), ('song', 233), ('serial', 231), ('review', 219), ('zealand', 218), ('team', 206), ('win', 203), ('bayya', 198), ('comedy', 197), ('india', 195), ('game', 193), ('film', 192), ('congratulations', 192), ('ever', 185), ('life', 184), ('fan', 182), ('nz', 182), ('cinema', 181), ('mahesh', 180), ('final', 180), ('upload', 179), ('arey', 177), ('acting', 171), ('voice', 167), ('superb', 164), ('face', 153), ('help', 153), ('full', 150), ('shannu', 150), ('music', 148), ('bagundhi', 147), ('back', 147), ('jai', 145), ('boss', 145), ('fans', 143), ('camera', 140), ('class', 139), ('short', 138), ('real', 138), ('big', 137), ('icc', 137), ('happy', 136), ('app', 136), ('bhai', 134), ('waiting', 131), ('oil', 126), ('support', 124), ('mam', 123), ('bhayya', 123), ('series', 123), ('history', 119), ('show', 118), ('stokes', 118), ('link', 117), ('middle', 116), ('software', 116), ('prank', 115), ('hair', 110), ('puri', 110), ('hero', 109), ('chepandi', 106), ('dance', 105), ('sudheer', 104), ('action', 101), ('chi', 101), ('free', 100), ('played', 99), ('water', 96), ('call', 96), ('winner', 94), ('explain', 94), ('release', 92), ('recipe', 92), ('youtube', 90), ('tv', 90), ('job', 89), ('watch', 89), ('black', 89), ('watching', 88), ('koncham', 87), ('player', 86), ('sindhu', 86), ('awesome', 85), ('fake', 85), ('ben', 85), ('worst', 84), ('heart', 84), ('pettandi', 84), ('god', 83), ('master', 82), ('beautiful', 82), ('feel', 82), ('bgm', 81), ('fast', 81), ('indian', 81), ('promo', 79), ('waste', 78), ('work', 78), ('man', 77), ('money', 77), ('background', 75), ('fire', 75), ('climax', 74), ('telangana', 74), ('vs', 74), ('version', 74), ('hit', 73), ('iphone', 73), ('whatsapp', 73), ('andaru', 72), ('movies', 72), ('problem', 72), ('set', 71), ('comments', 71), ('episodes', 71), ('character', 70), ('cute', 70), ('cheating', 70), ('brazil', 70), ('bigg', 69), ('seen', 69), ('play', 69), ('bobby', 69), ('performance', 68), ('download', 67), ('english', 67), ('people', 66), ('family', 66), ('trs', 66), ('could', 66), ('ball', 66), ('abba', 65), ('ammai', 65), ('baby', 65), ('rules', 65), ('subscribe', 64), ('lol', 63), ('need', 63), ('david', 63), ('newzealand', 63), ('nuv', 62), ('chudandi', 62), ('annayya', 62), ('luck', 62), ('challa', 61), ('today', 61), ('home', 61), ('phones', 61), ('keka', 60), ('tips', 60), ('excellent', 60), ('lost', 60), ('chetta', 59), ('end', 59), ('wow', 59), ('screen', 58), ('director', 58), ('editing', 58), ('android', 58), ('send', 58), ('virus', 58), ('laptop', 57), ('house', 57), ('loss', 57), ('side', 57), ('anil', 57), ('pettu', 56), ('wait', 56), ('vizianagaram', 56), ('create', 56), ('charging', 56), ('skin', 55), ('power', 55), ('case', 55), ('live', 55), ('vanta', 55), ('concept', 54), ('wrong', 54), ('pakistan', 54), ('level', 53), ('cool', 53), ('account', 53), ('rojulu', 53), ('captain', 53), ('nijam', 52), ('cheyocha', 52), ('update', 52), ('chicken', 52), ('bhargavi', 52), ('chudali', 51), ('prasad', 51), ('miss', 51), ('vadu', 51), ('bb', 51), ('vachindhi', 51), ('share', 51), ('unboxing', 51), ('definitely', 51), ('cream', 50), ('star', 50), ('trailer', 50), ('abhi', 50), ('loo', 50), ('dear', 50), ('battery', 50), ('samsung', 50), ('anchor', 49), ('check', 49), ('allu', 49), ('beckham', 49), ('paul', 49), ('fun', 48), ('chesthe', 48), ('suggest', 48), ('arjun', 48), ('clear', 48), ('kcr', 48), ('mobiles', 48), ('gaming', 48), ('pubg', 48), ('williamson', 48), ('unnaru', 47), ('cheyacha', 47), ('pedda', 47), ('year', 47), ('bindu', 47), ('congrats', 47), ('information', 47), ('jodi', 46), ('block', 46), ('start', 46), ('weight', 46), ('medha', 46), ('surya', 46), ('right', 46), ('google', 46), ('mexico', 46), ('way', 46), ('aadi', 45), ('vastundi',  ...

# %%
top_k_words,_ = zip(*fdist.most_common(k))
top_k_words = set(top_k_words)
def keep_top_k_words(text):
    return [word for word in text if word in top_k_words]

top_k_words_sentences= []
for text in data['telugu']:
    top_k_words_sentences.append(keep_top_k_words(text))
print(data['telugu'][:100])
top_k_words_sentences[:100]
# Out:
# 0                       [judges, cheysey, daka, programme, chuddam, manestey]
# 1                  [kamma, koritala, gaadu, kavalni, chetta, cinema, teesadu]
# 2     [karthika, deepam, timing, marchesthe, intlo, mandi, matches, chudachu]
# 3                      [kick, veeru, yenni, chusinaa, chudali, anipisthundhi]
# 4                                                   [kothi, dancer, pampandi]
#                                        ...
# 95                                       [aadiri, poendi, block, baster, hit]
# 96             [aadollapataki, aadollu, magavalla, pataki, magavallu, veyali]
# 97                                    [aadu, cheppedhe, lovada, sodhi, sodhi]
# 98                     [aadu, koddo, kastho, unnode, aadu, pavement, payment]
# 99                                           [aadu, nag, dharidhrapu, adhava]
# Name: telugu, Length: 100, dtype: object
# [[],
#  ['chetta', 'cinema'],
#  ['intlo', 'mandi', 'matches'],
#  ['chudali'],
#  [],
#  ['andaru', 'pothe'],
#  [],
#  ['love', 'bgm', 'movie', 'chepandi'],
#  [],
#  [],
#  ['music', 'matalu'],
#  ['negative', 'character', 'moham', 'moham'],
#  [],
#  ['ntr', 'vedava'],
#  [],
#  ['chei'],
#  ['tappa'],
#  ['phone'],
#  ['photo'],
#  ['navvu'],
#  ['bokka', 'screen', 'time', 'bokka'],
#  [],
#  [],
#  ['action', 'chudaleka'],
#  ['alanti'],
#  [],
#  ['anchor', 'action'],
#  ['ardham'],
#  ['chayandi', 'swamy'],
#  ['action'],
#  ['action'],
#  ['serial'],
#  ['short', 'story', 'papa', 'story'],
#  [],
#  [],
#  ['sri', 'waste'],
#  ['funny'],
#  ['voice', 'sri', 'sai', 'prasad', 'voice'],
#  ['baguntundi', 'face'],
#  ['ayya', 'baabu'],
#  ['title', 'master', 'pettu'],
#  ['title', 'views', 'cheyala'],
#  ['unnaru'],
#  ['close'],
#  [],
#  ['waste', 'job', 'job'],
#  [],
#  ['full', 'movie'],
#  ['aadhi', 'combination'],
#  ['aadhi'],
#  ['aadhi', 'chance', 'evvandi'],
#  ['aadhi', 'chalu'],
#  ['aadhi', 'bhanu', 'jodi'],
#  ['aadhi', 'program'],
#  ['aadhi', 'chetta', 'climax'],
#  ['aadhi', 'gadi', 'action'],
#  ['aadhi', 'koncham', 'mental'],
#  ['aadhi', 'vadiki', 'fan', 'feeling'],
#  ['aadhi'],
#  ['aadhi'],
#  ['aadhi', 'performance', 'keka'],
#  ['aadhi', 'superb', 'aadhi', 'song'],
#  ['aadhi', 'awesome', 'keka', 'done', 'job'],
#  ['aadi', 'chanti'],
#  ['aadi', 'chanti', 'superb'],
#  ['aadi'],
#  ['aadi', 'miss', 'sudheer'],
#  ['aadi', 'show', 'songs', 'jai', 'aadi'],
#  ['aadi', 'favourite'],
#  ['aadi', 'superb', 'whole', 'industry', 'aadi'],
#  ['aadi', 'man', 'show', 'punches'],
#  ['aadi', 'punches', 'highlight'],
#  ['aadi', 'punches', 'jai', 'aadi'],
#  ['aadi', 'ram', 'prasad', 'combination'],
#  ['aadi', 'skit', 'level'],
#  ['aadi', 'sudheer', 'big', 'fan'],
#  ['aadi', 'cute'],
#  ['aadi', 'telangana'],
#  ['aadi', 'yekkada', 'aadi', 'aadi', 'skit'],
#  ['aadi'],
#  ['aadi', 'full', 'untadi'],
#  ['aadi'],
#  ['aadi', 'gadi', 'chettha', 'unnai'],
#  ['aadi', 'skit', 'punches', 'enjoy'],
#  ['aadi', 'comedy', 'radu', 'comedy', 'sudheer'],
#  ['aadi', 'manchu', 'skit', 'ladu', 'promo', 'ladu'],
#  ['aadi', 'punches', 'time', 'petandi', 'evaraina'],
#  ['aadi', 'love', 'story', 'keka', 'bayya'],
#  ['aadi'],
#  ['aadi', 'action'],
#  ['aadi', 'nuv', 'edo', 'face', 'stop'],
#  ['aadi', 'punches', 'ram', 'prasad', 'punches', 'punches'],
#  ['aadi', 'ram', 'prasad', 'show'],
#  ['aadi'],
#  [],
#  ['block', 'hit'],
#  [],
#  ['sodhi', 'sodhi'],
#  [],
#  []]

# %%
final_data = []

new2oldindex_map = {}

old_index = 0
new_index = 0
# for text  in top_k_words_sentences:
#     string=text.split()
#     for word in string:
#         if len(string)<=1:
#             text.replace(word,"")

for text in top_k_words_sentences:
    if(len(text) >=6):
        new2oldindex_map[new_index] = old_index
        final_data.append(text)
        new_index += 1
        
    old_index += 1
texts=final_data
print("Total docs before processing: ", len(top_k_words_sentences))
print("Total docs after processing: ", len(final_data))
# Out:
# Total docs before processing:  23857
# Total docs after processing:  517

# %%
import gensim.corpora as corpora

id2word = corpora.Dictionary(final_data)

corpus = []
for text in final_data:
    new = id2word.doc2bow(text)
    corpus.append(new)

# %%
corpus[:10]
# Out:
# [[(0, 1), (1, 2), (2, 1), (3, 1), (4, 1)],
#  [(0, 1), (5, 1), (6, 3), (7, 1)],
#  [(8, 1), (9, 1), (10, 2), (11, 1), (12, 1)],
#  [(13, 1), (14, 1), (15, 1), (16, 1), (17, 2), (18, 1), (19, 1)],
#  [(20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1)],
#  [(20, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1)],
#  [(32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1)],
#  [(38, 1), (39, 2), (40, 1), (41, 2)],
#  [(42, 1), (43, 2), (44, 1), (45, 1), (46, 1)],
#  [(47, 1), (48, 1), (49, 1), (50, 2), (51, 1)]]

# %% [markdown]
# # Model Development

# %%
import gensim
# lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
#                                            id2word=id2word,
#                                            num_topics=10,
#                                            random_state=100,
#                                            update_every=1,
#                                            chunksize=50,
#                                            passes=10,
#                                            alpha="auto",
#                                            per_word_topics = True)

# %%
from gensim.models import CoherenceModel
# coherence_model_lda=CoherenceModel(model=lda_model,texts=final_data,dictionary=id2word)
# coherence_lda=coherence_model_lda.get_coherence()
# coherence_lda

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                   id2word=id2word,
                                                   num_topics=num_topics,
                                                   update_every=1,
                                                   chunksize=50,
                                                   passes=10,
                                                   alpha="auto",
                                                   random_state=12                                                   
                                               )

        model_list.append(model)
        coherencemodel = CoherenceModel(model=model,texts=texts, corpus=corpus, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        print(num_topics,"Topics Completed\n")
    return model_list, coherence_values

# %%
import matplotlib.pyplot as plt
limit=15; start=3; step=1;
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, 
                                                       limit=limit,start=start, step=step)

x = range(start, limit, step)
plt.plot(x,coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
# Out:
# 3 Topics Completed
#
# 4 Topics Completed
#
# 5 Topics Completed
#
# 6 Topics Completed
#
# 7 Topics Completed
#
# 8 Topics Completed
#
# 9 Topics Completed
#
# 10 Topics Completed
#
# 11 Topics Completed
#
# 12 Topics Completed
#
# 13 Topics Completed
#
# 14 Topics Completed

# %%
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 3  has Coherence Value of 0.528
# Num Topics = 4  has Coherence Value of 0.5584
# Num Topics = 5  has Coherence Value of 0.5793
# Num Topics = 6  has Coherence Value of 0.557
# Num Topics = 7  has Coherence Value of 0.6155
# Num Topics = 8  has Coherence Value of 0.5874
# Num Topics = 9  has Coherence Value of 0.5845
# Num Topics = 10  has Coherence Value of 0.5731
# Num Topics = 11  has Coherence Value of 0.5592
# Num Topics = 12  has Coherence Value of 0.5446
# Num Topics = 13  has Coherence Value of 0.5505
# Num Topics = 14  has Coherence Value of 0.5539

# %%
# Select the optimal model and check the topics (if required)
optimal_model = model_list[3]
#model_topics = optimal_model.show_topics(formatted=False)
print(optimal_model.print_topics())
# Out:
# [(0, '0.086*"england" + 0.050*"win" + 0.047*"india" + 0.034*"another" + 0.033*"beat" + 0.028*"content" + 0.028*"country" + 0.022*"newzealand" + 0.021*"team" + 0.018*"hero"'), (1, '0.064*"support" + 0.051*"telangana" + 0.045*"love" + 0.035*"media" + 0.029*"power" + 0.022*"arey" + 0.022*"story" + 0.020*"yentha" + 0.019*"episode" + 0.017*"kcr"'), (2, '0.046*"match" + 0.038*"superb" + 0.032*"song" + 0.030*"show" + 0.028*"funny" + 0.026*"greatest" + 0.025*"ever" + 0.023*"real" + 0.022*"stokes" + 0.020*"hard"'), (3, '0.082*"world" + 0.073*"cup" + 0.044*"dhoni" + 0.037*"virus" + 0.034*"shannu" + 0.034*"cricket" + 0.033*"icc" + 0.028*"zealand" + 0.028*"final" + 0.027*"nz"'), (4, '0.061*"jai" + 0.047*"class" + 0.045*"madhu" + 0.045*"middle" + 0.036*"film" + 0.029*"telangana" + 0.027*"mahesh" + 0.026*"short" + 0.023*"ina" + 0.022*"music"'), (5, '0.092*"movie" + 0.050*"fan" + 0.026*"big" + 0.023*"orey" + 0.020*"winner" + 0.020*"acting" + 0.019*"emotional" + 0.014*"ashwin" + 0.014*"guru" + 0.014*"ntr"')]

# %%
test_doc = corpus[100]
print(corpus[100])
vector=sorted(optimal_model.get_document_topics(test_doc),key=lambda x: x[1],reverse=True)
print(vector)
# Out:
# [(106, 1), (251, 1), (348, 1), (349, 1), (350, 2), (351, 3)]
# [(3, 0.50657207), (5, 0.40757126), (1, 0.02566743), (0, 0.023018215), (4, 0.01908678), (2, 0.018084232)]

# %% [markdown]
# # Visualization

# %%
import pyLDAvis
import pyLDAvis.gensim_models

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(optimal_model, corpus, id2word, mds="mmds")
pyLDAvis.save_html(vis,"lda.html")
vis
# Out:
# e:\softwares\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.172159  0.260341       1        1  23.750898
# 1      0.320074  0.005139       2        1  17.012581
# 0     -0.300943 -0.020212       3        1  15.825599
# 4      0.162169 -0.265800       4        1  15.164805
# 5      0.126425  0.254041       5        1  14.439989
# 2     -0.135566 -0.233509       6        1  13.806129, topic_info=        Term       Freq      Total Category  logprob  loglift
# 375    world  67.000000  67.000000  Default  30.0000  30.0000
# 71     movie  46.000000  46.000000  Default  29.0000  29.0000
# 484  england  47.000000  47.000000  Default  28.0000  28.0000
# 524      cup  60.000000  60.000000  Default  27.0000  27.0000
# 171  support  38.000000  38.000000  Default  26.0000  26.0000
# ..       ...        ...        ...      ...      ...      ...
# 192   laptop   3.603414   4.290498   Topic6  -4.8778   1.8055
# 439     cena   3.546582   4.232117   Topic6  -4.8937   1.8033
# 467    match  21.850775  32.280993   Topic6  -3.0754   1.5898
# 551  respect   8.139155  12.382527   Topic6  -4.0630   1.5605
# 550   played   5.556221   9.209458   Topic6  -4.4448   1.4747
#
# [231 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 615       2  0.518821       10
# 615       5  0.415057       10
# 13        6  0.826521     abba
# 156       6  0.872923  account
# 20        5  0.965063   acting
# ...     ...       ...      ...
# 410       1  0.948086    worst
# 571       3  0.816072    years
# 279       2  0.971986   yentha
# 522       1  0.725180  zealand
# 522       3  0.252237  zealand
#
# [207 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 2, 1, 5, 6, 3])

# %% [markdown]
# # Testing

# %%
#new_sentence ="esari world cup india gelustundi"
#new_sentence ="ntr acting movies lo baguntundi"
#new_sentence ="india team lo virat form loki vacchadu"
#new_sentence = "kcr trs ki goppa nayakudu"
#new_sentence = "middle class madhu comedy super"
new_sentence="Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu"

# %%
import numpy as np
bow = id2word.doc2bow([word for word in new_sentence.split()])
topics = sorted(optimal_model.get_document_topics(bow), key=lambda x: (x[1]), reverse=True)

# Print the top topic and its associated percentage
print(bow)
print("Top topic: ", optimal_model.show_topic(topics[0][0]))
temp=optimal_model.show_topic(topics[0][0])
topic_name=''
print(temp[0][0])
if(temp[0][0]=='world' or temp[0][0]=='england' or temp[0][0]=='match'):
    topic_name="Sports"
elif(temp[0][0]=='class' or temp[0][0]=='movie' or temp[0][0]=='jai'):
    topic_name="Entertainment (movies,serials,webseries)"
elif(temp[0][0]=='support'):
    topic_name="Politics"
else:
    topic_name="I'm Sorry I couldn't find!!"
    

#print("Top topic:",topics[0])
print("Associated %: ", np.round(topics[0][1]*100,2), "%")
print("The topic name: ",topic_name)
# Out:
# [(130, 1), (560, 1)]
# Top topic:  [('england', 0.086173445), ('win', 0.049609683), ('india', 0.046990037), ('another', 0.034493823), ('beat', 0.032577883), ('content', 0.02829352), ('country', 0.028105302), ('newzealand', 0.021911457), ('team', 0.021315021), ('hero', 0.018139375)]
# england
# Associated %:  37.87 %
# The topic name:  Sports

# %%
testdata = pd.read_csv('testing.csv')
print (testdata)
# Out:
#                                                                        comment  \
# 0                                           "esari world cup india gelustundi"
# 1                                            "ntr acting movies lo baguntundi"
# 2                                     "india team lo virat form loki vacchadu"
# 3                                                  "kcr trs ki goppa nayakudu"
# 4                                            "middle class madhu comedy super"
# ..                                                                         ...
# 489                            Adult movies ekkuva ayyayi e madhya industry la
# 490                                         Adyna dabbu unte aa enjoyment veru
# 491  Ae serial lo chusina ede vishwasam movie bgm emo prati emotion ki ide bgm
# 492                                   Aegte onion hair oil review cheyandi sis
# 493                                 Aekkada tesukunnaru ee dresses online lona
#
#     topic predicted Actual Results
# 0            Sports         Sports
# 1     Entertainment  Entertainment
# 2            Sports         Sports
# 3          Politics       Politics
# 4     Entertainment  Entertainment
# ..              ...            ...
# 489   Entertainment  Entertainment
# 490          Sports  Entertainment
# 491        Politics  Entertainment
# 492          Sports  Entertainment
# 493   Entertainment         Sports
#
# [494 rows x 3 columns]

# %%
for x in testdata['comment']:
    print(x)
    testbow = id2word.doc2bow([word for word in x.split()])
    testtopics = sorted(optimal_model.get_document_topics(testbow), key=lambda x: (x[1]), reverse=True)
    
    temp=optimal_model.show_topic(testtopics[0][0])
    topic_name=[]
    if(temp[0][0]=='world' or temp[0][0]=='england' or temp[0][0]=='match'):
        topic_name.append("Sports")
    elif(temp[0][0]=='class' or temp[0][0]=='movie' or temp[0][0]=='jai'):
        topic_name.append("Entertainment (movies,serials,webseries)")
    elif(temp[0][0]=='support'):
        topic_name.append("Politics")
    else:
        topic_name.append("I'm Sorry I couldn't find!!")
    print(topic_name)
    print("\n")
    testdata['topic']=x in topic_name
# Out:
# "esari world cup india gelustundi"
# ['Sports']
#
#
# "ntr acting movies lo baguntundi"
# ['Entertainment (movies,serials,webseries)']
#
#
# "india team lo virat form loki vacchadu"
# ['Sports']
#
#
# "kcr trs ki goppa nayakudu"
# ['Politics']
#
#
# "middle class madhu comedy super"
# ['Entertainment (movies,serials,webseries)']
#
#
# Dhoni next world cup ki vuntada
# ['Sports']
#
#
# steve smith icc rules follow avvaledhani ban chesaru
# ['Sports']
#
#
# Aa Karthika deepam timing marchesthe intlo chala mandi matches chudachu
# ['Sports']
#
#
# trs party sarigga panichesthundhi
# ['Politics']
#
#
# Aa kothi dancer ni pampandi mundu
# ['Sports']
#
#
# williamson best test batsman
# ['Sports']
#
#
# Aa Love Track BGM A Movie LoDho Yavaraina Chepandi Bhiya
# ['Sports']
#
#
# Aa music entra babu cheppadaniki matalu levu
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa negative Character artist moham achaam kothi moham la vundhi
# ['Sports']
#
#
# Aa NTR gaadu vangaveeti mohana Ranga gaari ni champimchina lucha vedava
# ['Sports']
#
#
# Aa penta mundaliddariki vere panemi ledu vaalla venakala padatam tappa
# ['Sports']
#
#
# Aa phone konali bro plz tell me
# ['Sports']
#
#
# AA photo pettaledhu gaa meku vundhi raa
# ['Sports']
#
#
# Aa pillaa navvu kosamaina chudochu
# ['Sports']
#
#
# Aa poorna ki Anni closeplu bokka screen time bokka
# ['Sports']
#
#
# Aa Poorna ni tesiveyandi ra samy
# ['Sports']
#
#
# Aa promotions chesentha kharma enti
# ['Sports']
#
#
# Aa rajyam over action ee pornami over expression chudaleka chacchela unnam
# ['Sports']
#
#
# Aa rakshasi ni chaniponivvu alanti athayya lu chavali
# ['Sports']
#
#
# Aa rojani tesi dobbandi inka baguntadi
# ['Sports']
#
#
# Aa rojullo anchor over action ela vundedi
# ['Sports']
#
#
# aa sada ki varshini performence yendhuku nachindho naku ardham kavatledhu
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa sarayu eleminate chayandi swamy
# ['Sports']
#
#
# Aa satya gaadi over action chudalekhapotunnam raa babu
# ['Sports']
#
#
# Aa satya over action chesthunnadu
# ['Sports']
#
#
# aa serial theseyandi ra meeku Dhandam pedatha
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa short story papa spyder lo rakul story cheppindhe
# ['Politics']
#
#
# Aa soodi gadu yemanna judge aa
# ['Sports']
#
#
# Aa sreeraam gadiki voting ledhu
# ['Sports']
#
#
# Aa sri ramchandra gadu waste aa bro
# ['Politics']
#
#
# aa task knchm diff ga funny ga try chyandi
# ['Sports']
#
#
# Aa teacher voice sri chaitanya vijayawada sai bhavan physics prasad sir voice laane undiraa
# ['Politics']
#
#
# Aa thammudini change cheste baguntundi Aa face chudalekapothunnam
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa thapana zoom veyakandi ayya baabu
# ['Sports']
#
#
# Aa title endira natraj enti master ani pettu
# ['Politics']
#
#
# Aa title enti views kosam inta cheyala
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa train lo ekkuvaga valle unnaru anadu bro
# ['Entertainment (movies,serials,webseries)']
#
#
# Aa varsha close up thagginchandira Chudtuntey chiraku vastunde
# ['Sports']
#
#
# Aa vedio appudu tesavu ra bevakub
# ['Sports']
#
#
# Aa waste Nandu gadu Tulasi kee job lakunda chasadu job untha aa fee Tulasi pay chasadi kada
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadhar number petukondi security purpose
# ['Sports']
#
#
# Aadhavan Aadhavan full movie com
# ['Sports']
#
#
# Aadhi & sudhir deadly combination
# ['Sports']
#
#
# Aadhi anna meru really great meru appudu navuthu navisthu undali anna
# ['Sports']
#
#
# Aadhi anna naku kuda meeri okka chance evvandi pls
# ['Sports']
#
#
# Aadhi anna vunte chalu navvule navvulu
# ['Sports']
#
#
# Aadhi bhanu super excited Jodi A sandya tvaraga velipovali
# ['Sports']
#
#
# Aadhi brother nikosame program chustunna
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadhi chanipovadam nachaledhu chetta climax
# ['Politics']
#
#
# Aadhi gadi over action akkuva indhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadhi gadiki koncham mental vundhi
# ['Sports']
#
#
# Aadhi gadu kojja vadiki fan feeling ekuva bokada gadu adu
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadhi imanuwal super super varasha super super super
# ['Sports']
#
#
# Aadhi Ni thiseyandi ra babu vado talanoppi
# ['Sports']
#
#
# Aadhi performance super keka adurse etc
# ['Sports']
#
#
# Aadhi singing superb and Priyamani aadhi song chincheshatu
# ['Sports']
#
#
# Aadhi you did awesome keka you did a well done job
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi & chanti super singer also
# ['Sports']
#
#
# Aadi & chanti was sung extremely superb
# ['Sports']
#
#
# Aadi and Ramprasad Anna super
# ['Sports']
#
#
# Aadi and ramprasad combo super but miss sudheer bro
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi anna e show lo all in one songs skits jai aadi anna
# ['Sports']
#
#
# Aadi anna is one of my favourite
# ['Sports']
#
#
# Aadi anna nv superb anna One and only best comedian in whole industry its aadi
# ['Sports']
#
#
# Aadi anna one man rock the show With super punches
# ['Sports']
#
#
# Aadi anna punches are always highlight
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi Anna punches super jai hyper Aadi Anna always super talented
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi anna Ram Prasad anna super combination
# ['Sports']
#
#
# Aadi Anna skit Vera level super super
# ['Politics']
#
#
# Aadi Anna Sudheer anna big fan nenu
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi Anna super talented super cute
# ['Sports']
#
#
# Aadi Anna ur telangana yesudas keep it up u should become yesudas
# ['Politics']
#
#
# Aadi anna yekkada vunte akkada navvula varsham aadi anna kosarame chustunnam aadi lekunte skit ledu
# ['Sports']
#
#
# Aadi bro yediste baada anpinchindi
# ['Sports']
#
#
# Aadi dialogs full hearting untadi
# ['Sports']
#
#
# Aadi gaaru meeru and indrja mem baga paadaru
# ['Sports']
#
#
# Aadi gadi punchu lu chettha ga unnai
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi garu mee skit lo super punches vunnayi enjoy every one
# ['Sports']
#
#
# Aadi ki comedy radu rash ga untavi adi comedy anari revenge antaru Sudheer ni chusi nerchuko
# ['Sports']
#
#
# Aadi Manchu Vishnu ni imitate chese skit ladu anti promo lo vundi ekada ladu
# ['Politics']
#
#
# Aadi manoj meda vese punches time petandi evaraina
# ['Sports']
#
#
# Aadi n dia love story keka intha acinima nachaledu bayya
# ['Politics']
#
#
# Aadi neepaata bokkala undi inkeppudu try cheyyaku ok na
# ['Sports']
#
#
# Aadi ni appandi ra babu madhya lo over action chudalaka pothunam
# ['Sports']
#
#
# Aadi nuv malli edo prb face chestav anipistundi better to stop dis type of videos
# ['Entertainment (movies,serials,webseries)']
#
#
# Aadi punches are auto ram prasad punches evari punches antee meekistam
# ['Sports']
#
#
# Aadi Ram Prasad best best of this show
# ['Sports']
#
#
# Aadi vishnu ni adukunnadhi theesesaru antha bayama vallante mallemalaki
# ['Sports']
#
#
# Aadiga endira nivu Ni kamam tho katakataladutunnavu
# ['Sports']
#
#
# Aadiri poendi block baster hit
# ['Sports']
#
#
# Aadollapataki aadollu magavalla pataki magavallu veyali
# ['Sports']
#
#
# Aadu Cheppedhe Lovada Sodhi malli Sodhi Lekunda Anta
# ['Sports']
#
#
# aadu koddo kastho unnode kada aadu pavement payment enti
# ['Sports']
#
#
# Aadu nag sir kadhu dharidhrapu Adhava
# ['Sports']
#
#
# Aaduku sita aantee shilpa ki kopam
# ['Sports']
#
#
# Aagadu cinemaki vaitla ni kuda alaney tittaru
# ['Sports']
#
#
# Aagalekapothunnannaa athruthaga undhi
# ['Sports']
#
#
# Aagu aagu idhedho koosantha workout ayyetattu undhi
# ['Sports']
#
#
# Aah chalu jaffa negative spread cheyoddu
# ['Sports']
#
#
# Aah musalidhi atla nachindhi ra mukku gaa
# ['Sports']
#
#
# Aakariki e siutuation ki vacharu anamaata chusevallu
# ['Sports']
#
#
# Aakash adukodaniki velladu chi cheththa seriel
# ['Sports']
#
#
# Aakash ki gatham gurthosthundemo chudali
# ['Entertainment (movies,serials,webseries)']
#
#
# Aakash ki kadu mental serial director ki vadini join cheyandi first mental hospital lo
# ['Sports']
#
#
# Aakash meru malli acter ga ravali
# ['Entertainment (movies,serials,webseries)']
#
#
# Aakhasa veedhilo full movie in telugu
# ['Sports']
#
#
# aalani pogadandi antee kaani gorrelaaga sudheer rashmi anakandi vaalavalla em use ledu
# ['Entertainment (movies,serials,webseries)']
#
#
# aallanu champatam rendu okke super line annaya champeshav po love you
# ['Politics']
#
#
# Aana miru new you tube start chesay valaki training estara
# ['Sports']
#
#
# Aana nuvu Kurnool lo nandikotkur ki ra
# ['Sports']
#
#
# aana type c cable chaepandi aana
# ['Sports']
#
#
# aandaru bagudalli aandllonafemli vundalli
# ['Sports']
#
#
# Aanya super aanya super aanya super super super
# ['Sports']
#
#
# Aapara swamy chudaleka pothannam
# ['Sports']
#
#
# aapu bayya nuv anta ledu movie its jst avg audience talk vere vidhamga vundi bayata
# ['Entertainment (movies,serials,webseries)']
#
#
# aarey aa sudheer gaadiki andhuku antha over auction
# ['Entertainment (movies,serials,webseries)']
#
#
# Aarina over action barinchalakapothunnamu aapakunda maatladuthundi
# ['Sports']
#
#
# Aasalu chodaleka potunamu chala chirakuga uodi
# ['Sports']
#
#
# aata antaru oka range lo undi ani
# ['Sports']
#
#
# Aathulu kanapaduthunnai chooskondi
# ['Sports']
#
#
# Aatu eetu oopu Sunny Anna thopu East or west Sunny Anna best
# ['Entertainment (movies,serials,webseries)']
#
#
# Aavaryna use chesara e cream results undha miku please reply me
# ['Sports']
#
#
# Aavida mukhasthuthi kosam kathalu cheppaledhu nijaalu cheppindhi
# ['Sports']
#
#
# Aba e movie chusta chalu Edo felling vastundi naku vacha felling muku vasta aba oka like
# ['Entertainment (movies,serials,webseries)']
#
#
# Ababaa elantie video never before ever after
# ['Sports']
#
#
# abababab em short film broo mind blowing broo trendy pelli chupulu
# ['Entertainment (movies,serials,webseries)']
#
#
# Abaddame adadu sriram easy ga telustundi
# ['Sports']
#
#
# Abai antaga set kaledhu vaisu ki
# ['Entertainment (movies,serials,webseries)']
#
#
# Abai eti ekede padte akada vedustunadu
# ['Sports']
#
#
# Abayilu intha cool kadhu real ga
# ['Entertainment (movies,serials,webseries)']
#
#
# abba abba em ayina vundhi anna laptop
# ['Sports']
#
#
# Abba abba what a romantic jodi s n r
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba am character superr chesindi ame superr
# ['Politics']
#
#
# Abba artist kani ekkada padataro gani superga set avutaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba asalu super anna kani chaala thakkuve
# ['Sports']
#
#
# Abba astha chemma movie gurtu vacchindi
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba bro love letter anagaane pakkana unna friends Gola chudaali chaala enjoy chestunnaru
# ['Politics']
#
#
# Abba Chala bags vundi jatara annavalu like yesukondi
# ['Sports']
#
#
# Abba e deepam eppudu aripothademo Nune poyyakunda okovachuga
# ['Sports']
#
#
# ABBA eam chepitiri eam chepitiri
# ['Sports']
#
#
# Abba edena first and last episode rishi navve episode
# ['Politics']
#
#
# abba edhi chusi nenu chala bhaypaddanu
# ['Sports']
#
#
# Abba ee cinema ni enni sarlu chusina bore kottadhu
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba em dhyram rgv garu mi taravarhey evaru ayina rgv fns like here
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba em song raa babu asalu veltala mind nunchi hema chandra champenav
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba em tisarandi superb ilantivallu dorikithe gundello petti chusukuntanu
# ['Sports']
#
#
# Abba enka sagadheste seriyal value pothundhi
# ['Sports']
#
#
# Abba enthabagundho heroin ame character indulo super vndhi elanti akkunte bagundu anpisthundhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba i am waiting to see this song on YouTube
# ['Politics']
#
#
# ABBA laksha pettina security ledu
# ['Sports']
#
#
# Abba Love you Diya and adhi your emotions and acting super expirations super
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba m love story broo ekdham undhi super
# ['Politics']
#
#
# Abba mahanubhavudu Arudra garu ela cheskunnaru evidani ela bharincharu e egoistic ni
# ['Sports']
#
#
# abba mastigundhi bhayi bale hearting touching song best song forever lyrics superb Luved it
# ['Sports']
#
#
# Abba meeru nijanga devtha madum e video ma Amma ki chupista
# ['Sports']
#
#
# Abba Mohan Anna baga tesavu abba
# ['Sports']
#
#
# Abba music emanna vundha anna superb anna superb
# ['Sports']
#
#
# Abba ne news malu chala prank asalu e Anna na yapuduu tistaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba ne yabba Nuvu ne sodhi review Blood circulation enti ra
# ['Sports']
#
#
# abba no comments to say i loved this a lot ee girl ur assum looking like angel that gye is nice
# ['Entertainment (movies,serials,webseries)']
#
#
# Abba pournami ki dimma tirigi bomma kanabadindi Super Aakash
# ['Sports']
#
#
# Abba rishi sir mimmalni chustunte alage chudalanipistundi
# ['Politics']
#
#
# Abba sketch evaru gisaro teliyadhogani bale super ga undi
# ['Entertainment (movies,serials,webseries)']
#
#
# abba sudher maga jathi animutem nuvvu chosi
# ['Sports']
#
#
# Abba super duck voice meeru mimicry try cheyyochu
# ['Politics']
#
#
# Abba super video anna Starting nunchi end daka full navulu
# ['Sports']
#
#
# ABBA too much mari too much lokesh ni pappu ga fix chesesaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbabba am song avaru rasaro kani feeling adiripoindi rojukosari ina vilnalanipistundi
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbabbabbabba emi thisthiri emi thisthiri bhaley ga vundhi
# ['Sports']
#
#
# abbah super song nak chala antey chalaa istam fida aipoy e song ki super
# ['Sports']
#
#
# Abbai character bagundi and totally good one
# ['Politics']
#
#
# Abbai matalu chala bagunnai a ammailaga
# ['Sports']
#
#
# Abbailaki oil and pimples vasthunte taggadanaki medicine chrppandi
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbailu inka mudurlu kada ami takkuva kadu
# ['Sports']
#
#
# Abbayalani yedavalni cheyataniki thesinattunnaru
# ['Sports']
#
#
# abbayi ammayi eddaru expressions chimpesaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbayi vaice bhagunte highlight undedhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbi chala kalam iendhi andhuku miss iyyavvu
# ['Sports']
#
#
# Abbo anchor shiva na kottuku sastaru pakka idi
# ['Sports']
#
#
# Abbo idhi endhukante premanta movie scene
# ['Sports']
#
#
# Abbo ilanti concept tho serial eppudo vachhi kooda ipoindi le
# ['Entertainment (movies,serials,webseries)']
#
#
# Abbo negative talk chepthe kodthunaru ani chepu
# ['Politics']
#
#
# Abbo star hero craze okka serial techipettindi meku doctor babu garu
# ['Sports']
#
#
# Abbo super undi trailer Meelo enthamandiki nachindi trailer
# ['Entertainment (movies,serials,webseries)']
#
#
# abbo voice Dani over action chetta
# ['Politics']
#
#
# abboo miru dabbu tisukuni mammalni baagaa vadalakottatledaa
# ['Sports']
#
#
# Abdominal skin tightening ki video cheyandi mam please
# ['Entertainment (movies,serials,webseries)']
#
#
# Abdul kalam gurchi video cheyyandi
# ['Sports']
#
#
# abe oh faltu em telusu ra niku
# ['Politics']
#
#
# abha m undi kirrak Hort touching to the my life
# ['Sports']
#
#
# Abhi Anna I AM big fan of you shashi niku Manchi Jodi Anna pls okasri alochinchu anna
# ['Entertainment (movies,serials,webseries)']
#
#
# Abhi anna MAA tv ki valipoyaru
# ['Sports']
#
#
# Abhi anna mamulga win avvadu massive nd huge votes tho win avuthadu
# ['Sports']
#
#
# Abhi Anni neku challa baga nachutay le Ra vuddaloda
# ['Politics']
#
#
# Abhi bajana apura baabu game ade vallaku support chei
# ['Politics']
#
#
# Abhi chala over ga react aieyadu
# ['Sports']
#
#
# Abhi enduku gelichadu naannaa manasu nee thalakay
# ['Sports']
#
#
# Abhi fan aanukunta meeru vedio motham abhi bazana ne
# ['Politics']
#
#
# Abhi fans andharu harika ki vote vesthe abhi em ipovali mari
# ['Politics']
#
#
# Abhi gaadiki vesina votes Anni dandaga
# ['Sports']
#
#
# Abhi garu Mari ammaiyini aenduku marriage chesukovataledu
# ['Sports']
#
#
# Abhi garu super ga chsaru all the best & God bless you Palakollu ur female friend
# ['Politics']
#
#
# Abhi gurinchi bad ga chepthe bgodu
# ['Sports']
#
#
# Abhi harika conversation lo both did correct but just misunderstanding valla small fight
# ['Sports']
#
#
# Abhi is very gentle man winner pakka
# ['Sports']
#
#
# Abhi jai ki velthunnadu ani sohel edchi untadu
# ['Politics']
#
#
# Abhi ki vote veyalante e nbr ki missed cal ivvali
# ['Politics']
#
#
# Abhi ni harika nu thokeadem enti ra babu asalu nv direct abhi ki dappu kottadam apu
# ['Politics']
#
#
# Abhi nuvvanta naku chala ishtam yanta ishtam anta matallo chappalanta ishtam madhu
# ['Entertainment (movies,serials,webseries)']
#
#
# Abhi nuvvante naku chala istam e serial nikosam chusanu
# ['Entertainment (movies,serials,webseries)']
#
#
# Abhi waste his atitude too much nuvvu apu abhi bajana
# ['Politics']
#
#
# Abhi winner confirm ayyendi alredy
# ['Politics']
#
#
# Abhi winner yelagu vote for Akhil
# ['Politics']
#
#
# Abhijeet monal esthada respect vadu jaffa em takkuva kadu
# ['Politics']
#
#
# Abhijeet tho matladu ani monal ani abhi tho matladini taravata kopam tho aligi tittevadu
# ['Politics']
#
#
# Abhijeet tho sohel ariyana gurinchi annadu adi cheppale
# ['Politics']
#
#
# Abhijeet winner anedi mathram pakka
# ['Sports']
#
#
# Abhijeeth tharwatha Ariyana ra kukka
# ['Sports']
#
#
# Abhijith gurichi cheppandi anna
# ['Sports']
#
#
# Abhilash D bro review product bro review chesi return cheyala
# ['Sports']
#
#
# Abhinav Manikanta mirae na hero
# ['Sports']
#
#
# ABI thopu dhamuntay APU BB king winer
# ['Sports']
#
#
# Abijeet fans ayithe ekkada like kotandi
# ['Sports']
#
#
# Abijith chesina performance a movie song music adhi
# ['Sports']
#
#
# Abo ame adepenchavu bro heronini super
# ['Entertainment (movies,serials,webseries)']
#
#
# About Osama bin laden gurinchi pattava
# ['Sports']
#
#
# About TeluguBadi ane video lo untundi okasari check cheyyandi
# ['Sports']
#
#
# Absence account lo URL cheyalanutundhi maaku URL ledhu ela sir
# ['Sports']
#
#
# ACAN nundi endhuku drop ayyav bayya
# ['Entertainment (movies,serials,webseries)']
#
#
# Acchu guddhnatlu Nani gariki thammudi laa vuntaru meeru
# ['Sports']
#
#
# Accident ayina master name enti
# ['Politics']
#
#
# Accident marks ki use cheyacha sister
# ['Entertainment (movies,serials,webseries)']
#
#
# Acctual ga idhi chusi nijam anukuntaru nibba nibbis Kani idhi kuda scripted aa
# ['Sports']
#
#
# acharya lo mega mafia acting kante nee acting super bro
# ['Entertainment (movies,serials,webseries)']
#
#
# Acharya movie kante vedi action bagundi
# ['Politics']
#
#
# achina education motham debba thintadhi frank bagundhi kani naku nachaledhu sry ajay garu
# ['Entertainment (movies,serials,webseries)']
#
#
# Achu thaman gadini chusinate undhi
# ['Sports']
#
#
# achyutha kumari alrdy chesaru kotaru kuda
# ['Sports']
#
#
# Acne scars ki derma roler use cheyavachha
# ['Sports']
#
#
# Acp mari over ekkuvuga chesthundi acp madam over action baga ekkuvindi konchem thagginchukondi
# ['Sports']
#
#
# Acting a radhu kani short film kavala prema niku
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting adhurs expressions mamulaga levu keka
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting bagundhu Story bagundhi Nice concept
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting chalaa bagundhi anna all the best
# ['Entertainment (movies,serials,webseries)']
#
#
# acting chesavu so cute brother
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting cheyamate overaction chetharedhi
# ['Sports']
#
#
# Acting chimpesav bhayya superb story was awesome
# ['Politics']
#
#
# Acting chinchesadu ethanu short film chesthu cinema artist avalani korukuntuna
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting currect GA vundhi dabbing sarega ladhu
# ['Sports']
#
#
# acting eraga thesaru baya keka asalu
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting is same to same power star anna
# ['Politics']
#
#
# Acting keka iddaru ammayi looks Nd abbayi expressions super well done
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting lavel saripole bro Sry all the best
# ['Sports']
#
#
# Acting lo acting chesthunnaru andharu selfish Le rukmini thappa
# ['Entertainment (movies,serials,webseries)']
#
#
# Acting mari over ga vuodhi girl dhi
# ['Politics']
#
#
# Acting natural ga chala bagundi camera taking superb
# ['Sports']
#
#
# Acting nerpinchandi ra babu vellaki
# ['Sports']
#
#
# acting sem nani hero la unde bro
# ['Sports']
#
#
# Acting super Bro after hero nani nve second natural star broo
# ['Sports']
#
#
# Action chey akka over action kaadu
# ['Entertainment (movies,serials,webseries)']
#
#
# Action lu emotion lu kuda chese vacchu timing lo comedy pandalante adhi veellake sadhyam
# ['Sports']
#
#
# Action overaction movies vuntayi routine ekuva because of partiality
# ['Entertainment (movies,serials,webseries)']
#
#
# Action vundhi kabatte KGF biggest film ayyindhi
# ['Politics']
#
#
# Activa ki idi competation ivaledu
# ['Sports']
#
#
# Actor dhi actress dhi smile bagundhi
# ['Politics']
#
#
# Actors Acting Asalu Baledh Female Acting Over
# ['Sports']
#
#
# actors ni ekadi nundi patukastav ra babu intha correct ga set aiyaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Actors performance bagundi but story baaga lag chesthunattu anipisthundi
# ['Sports']
#
#
# Actress peru anto telidu kani super undi voice super amai matram super cute and pretty undi
# ['Politics']
#
#
# Actual ga nenu other country vlogs chudanu but mevi chustha
# ['Sports']
#
#
# Actual ga pixle size entha vuntundi anna
# ['Entertainment (movies,serials,webseries)']
#
#
# Actual navvu raaledhu Endhuku ante Dheeraj Anna unnadu kabbati
# ['Politics']
#
#
# Actual Vivek is winner but there is some thing wrong decision Rekha prakash wrong decision
# ['Sports']
#
#
# Actual winner saipallavi vellu waste
# ['Politics']
#
#
# Actually Acting super tejaswirao
# ['Sports']
#
#
# Actually dinni Phsylogical pricing antam ivi business yokka strategies
# ['Sports']
#
#
# Actually director gaari ki clarity missing
# ['Sports']
#
#
# actually e show lo anta excitement ladu jokes levy talusa nenu andariki fan but ado missing brother
# ['Entertainment (movies,serials,webseries)']
#
#
# Actually ee episode tarvathe Nagarjuna Kajal ni pagabattadu
# ['Politics']
#
#
# Actually film ki Pettina name ki aslu compared ledhu
# ['Entertainment (movies,serials,webseries)']
#
#
# Actually IAM big of u madam nenu mi video chustanu
# ['Entertainment (movies,serials,webseries)']
#
#
# Actually naa doubt kooda adhe ameke worst performer ichi malli ameke neethulu cheptunadu
# ['Sports']
#
#
# Actually nenu ela cheddam aanukunna but konni karanalavalla drop ayya
# ['Sports']
#
#
# Actually super undhi film I like it
# ['Entertainment (movies,serials,webseries)']
#
#
# Acv use chestapudu regular periods problem avuthadaa
# ['Sports']
#
#
# Adabatunu ee angle lo choopi prekshkulanu aakattukunnaru sheker kammula
# ['Sports']
#
#
# Adadhaniki adadhe shethruvu heroin meedha comments chustene thelusthadi
# ['Entertainment (movies,serials,webseries)']
#
#
# adadi kannu ethi chusina dialogue supr
# ['Politics']
#
#
# adadi sahinchi antha vareke magadi prema okasari adadi devshesthe magadu chave
# ['Entertainment (movies,serials,webseries)']
#
#
# adam kuda telidu Chala rude ga matladthunar
# ['Sports']
#
#
# Adangi gadu ravi and shannu gadu
# ['Sports']
#
#
# Adantha vaddu kani ee chetta serial first aapeyyandi chalu
# ['Sports']
#
#
# Adapillalu anthe entha tondaraga premistharo antha tondaraga marchipotharu
# ['Sports']
#
#
# Adapillani enni matalu antunnavu director
# ['Sports']
#
#
# ADAVALAKU VELUVA ECHINADUKU CHALABAGUNDI
# ['Sports']
#
#
# Adavallu andharu serial lo iddaru magavallu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adbhutham Speechless connedy
# ['Sports']
#
#
# Adbutam matramey Nijam asalu kadu
# ['Sports']
#
#
# Adbutham ane Peru ki taggattu undhi short film intense in it must watch
# ['Entertainment (movies,serials,webseries)']
#
#
# Adbutham nijanga adbutham ga vundi inka adbutham entante heroine voice supper vuntadhi
# ['Politics']
#
#
# Adbutham short film real ga adbutham ga undhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adbutham title super and title Adbutham la ga undhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adbutham video nijangane adbutham
# ['Sports']
#
#
# Add free subscription tesukondi
# ['Politics']
#
#
# Addi anna comedy timing vereleval Chipsav anna thagedhe le sing eragakotesav
# ['Sports']
#
#
# Addi anna Nv lenide show nadavadu
# ['Sports']
#
#
# Addi over action thagithe manchidi
# ['Sports']
#
#
# Addi super cute chala bagundi punchh
# ['Sports']
#
#
# addiripoindi waiting for movie
# ['Politics']
#
#
# address aduguthu heart attack vachinatlu padipondi bhayya public reaction ala vumtumdho chudali
# ['Politics']
#
#
# Address doddichinthala ganumantuni padu mandalprakasam district
# ['Sports']
#
#
# Ade chetho oo antava pata kuda vadalandi ayya
# ['Sports']
#
#
# Ade le ameki opp akhil unnadu kabatti ameke vestav le vote uu kani kani
# ['Politics']
#
#
# Ade magiccu ani eppudu vadutaru bro please cheppu
# ['Sports']
#
#
# Ade mari over ante ardhrathi chei
# ['Sports']
#
#
# Ade timeing undali marchankandi
# ['Sports']
#
#
# Adee show lo background dancer nunchi contestant master eppudu judge improvement
# ['Politics']
#
#
# Adee thanakaina ardam avvali kadaa
# ['Entertainment (movies,serials,webseries)']
#
#
# Adem bro papam vijay kuda kasta pade vachadu
# ['Sports']
#
#
# Adem ledu anee konchm ekuvu matladindi so chepadu ante
# ['Sports']
#
#
# Adento bayya kothi kallu taginattu ala oogesindhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adento reality ilavunte insta lo matram shannu bots trend chestaru
# ['Sports']
#
#
# Adevadanna edevadanna maa yash anna ki addavadanna
# ['Sports']
#
#
# Adevadanna edevadanna mahesh anna birthday ku addevadanna happy birthday mahesh anna
# ['Entertainment (movies,serials,webseries)']
#
#
# Adey ga rukumini yendhku fellings kaligenchadam stubborn ga vundachu ga
# ['Sports']
#
#
# Adhaina Sudheer anna vuntene baguntundhi
# ['Sports']
#
#
# Adharsh badu badu madoka waste gadu
# ['Politics']
#
#
# Adharu oka like vesukodhie friends
# ['Sports']
#
#
# ADHBUTHAM ATHYADBHUTHAM Teju the great
# ['Sports']
#
#
# Adhbutham short film sir adhnutham anthe and bgm kuda champesaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhe chudu main paper lo jathakam chustunde
# ['Sports']
#
#
# Adhe madam meeru gelavadam mukyam
# ['Sports']
#
#
# Adhe repeat chesi chesi tisthunaru serial
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhemo kani meku vundhanukunta Ravi ante baga negative feeling
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhenti full film Leda chetha na kodukulu
# ['Sports']
#
#
# Adhenti mistake mundu edharu babulani chupinchi epudu amayini chupistunaru
# ['Sports']
#
#
# Adhi and ram prasad me iddaru chaalu bro any show super hit
# ['Sports']
#
#
# Adhi and Sudheer anna ramprasad all are super performance
# ['Sports']
#
#
# Adhi andhariki telusu lera pooka
# ['Sports']
#
#
# Adhi anna a show lo vunna super ga punches vuntayi
# ['Sports']
#
#
# Adhi Anna me life journey gurinchi Naku e roje thelisindhi so nice Anna
# ['Sports']
#
#
# Adhi Anna ph no ivvndi sir Sudheer annadhi kuda
# ['Sports']
#
#
# Adhi Anna super Last lo highlight punches
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi Anna valle e show hit ayyendi
# ['Sports']
#
#
# Adhi Anna vunnathasepu mallemala top lo vuntadhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi annani chusi chala emotional iyyanu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi antay bro chuseyali manam
# ['Sports']
#
#
# Adhi ante pakkana vadini comment chaydame kodhiga comedy chay
# ['Sports']
#
#
# Adhi bava great God bless you Bava
# ['Politics']
#
#
# Adhi bhanu pair entha mandi ki ista
# ['Sports']
#
#
# Adhi bhanu vidipothara adhi sandhya ni pelli chesukuntada pls chepandhi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi bhanu vidipotharu adhi sandhya ni pelli chesukuntadhu ani anukunevallu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi bro same Dasaranarayana la unauvv same
# ['Sports']
#
#
# Adhi correct kadu adhi srivalli me nillabettindhi
# ['Sports']
#
#
# Adhi epudu ardham chesukudhile
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi gadi jealousy on sudheer anna
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi gadu chala over chesthunadu
# ['Sports']
#
#
# Adhi gadu overaction nduku madyalo
# ['Sports']
#
#
# Adhi gadu unte over action ekkuva untadhi pakkanollanu eppudu thakkuva chesthuntadu
# ['Sports']
#
#
# Adhi Gari lat dham no video yadhuku cut chesaru sugar ga unda ha comedy
# ['Politics']
#
#
# Adhi gari promo dialogue ekada undho chepandi
# ['Politics']
#
#
# Adhi Garu mehaboob int ichadu kada dhani Pina video cheyandi
# ['Sports']
#
#
# Adhi housetour laaga ledhu dongalaki house blueprint icchinattundhi dongatanam cheyadaaniki
# ['Sports']
#
#
# Adhi jasthitheluv chupicnchaddu sudeeranna gurichi thelusukoni matladu
# ['Sports']
#
#
# Adhi leakapothe clean ga double meaning words leakunda chala bagundhi show
# ['Sports']
#
#
# Adhi manaku ela thelusthundhi brother defective product ani
# ['Politics']
#
#
# Adhi manchu vishnu nee imitate chesindi ledu enti
# ['Politics']
#
#
# Adhi medam Naku aloe vera vadite naku growth chala avutadi medam
# ['Sports']
#
#
# Adhi meeru teesukune food dait ni batti kuda untundhi
# ['Sports']
#
#
# Adhi mikela thelsu serial end lo ani antunaru
# ['Entertainment (movies,serials,webseries)']
#
#
# adhi ni ladies left leg tho kotalu vadhu kojja
# ['Sports']
#
#
# Adhi niku chalaa balisindhi raa
# ['Sports']
#
#
# Adhi nivu koncham thagu Ni mokam chudu over ga entra Nivu sudhir ki potiya entra edhi
# ['Politics']
#
#
# Adhi nivu koncham thagu over ga entra
# ['Politics']
#
#
# Adhi nuv cheppakudadhu yekkuthado ledho mem chuskuntam
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi nv kuda roju roju Prasad la maripothunnav
# ['Sports']
#
#
# Adhi opukovadame meru chesina pedda mistake
# ['Sports']
#
#
# Adhi payment to bokka over dialogue Lahari vachinapudu nuv ekkaunav comedy cheyu anthi cheyudhu
# ['Sports']
#
#
# Adhi pk ante gorginers kuda vachi votu vesthstharu
# ['Sports']
#
#
# Adhi prank cheyadaniki ochindha Dhunnapothu laa thinadaaniki Ochindha
# ['Politics']
#
#
# Adhi puspha movie lo undi anna
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi s and indraja Garu super super ga padaru
# ['Sports']
#
#
# Adhi sandhya ni love chestunadhu ani anukunevsllu comment pls
# ['Politics']
#
#
# Adhi Sudheer anna set mothaniki anna undali ala ana
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi sudheer rashmi Roja garu super mee skits ante chala estam
# ['Entertainment (movies,serials,webseries)']
#
#
# Adhi sudher tho jokes thaginchu
# ['Sports']
#
#
# Adhi tanu worst performer ki nominate ennadu joke ga nomination gurinchi kadu
# ['Sports']
#
#
# Adhi telicast Chesi untey undehdi sir Siri ki janalu thanni Mari pampeyvallu
# ['Sports']
#
#
# Adhi telisi kuda endhuku pakkalu vestharu appudu mogudi viluva theliyadhu kadha
# ['Sports']
#
#
# Adhika dhana sampadanaki emi chayali
# ['Politics']
#
#
# Adhitya bro ki assal Hindi nerpodhu
# ['Sports']
#
#
# Adhitya ki hindhi rakuntane comedy ga vuntadhi script
# ['Sports']
#
#
# Adhitya rukku Lani kalapandi plz
# ['Sports']
#
#
# Adho doctor chepinatllu cheptundi
# ['Sports']
#
#
# Adhoka serial na malli daniki interview
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi ane name ni dia ani marchochu same alphabets to
# ['Sports']
#
#
# Adi anna nuvu eppudu happy ga vundali
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi anna nuvu yeppdu happy ga vudali anna adi chalu maku
# ['Sports']
#
#
# Adi Anna Prakasam distc mudubida niku thrugundadu
# ['Sports']
#
#
# Adi antha script only trp kosam anthe pelli ledu padu ledu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi beauty ah kallu unnaya bandadi adi
# ['Sports']
#
#
# Adi biography ki starting lo oka music vachindhi ga ey moive lo dho telusa evarikena
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi chanipokudadhu plz athani character ni unchandi
# ['Politics']
#
#
# Adi chanipoyaka dia brathikunda chanipoyinda ending clarity evvandi sir
# ['Sports']
#
#
# Adi chanuvu ekuvayi audienceni frndslaga treat chesthunaru kavachu nothing wrong
# ['Sports']
#
#
# Adi dhorababu super super super super
# ['Sports']
#
#
# Adi dia vellu eddaru kalisi unte happy ending ayyedhi Kani director ending mari darunanga thesadu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi director ki matrame telustadi brother
# ['Sports']
#
#
# Adi ela cheyalo chepandi Anna garu
# ['Politics']
#
#
# Adi emotion super sudder sothaa tamunla chuskuntadu
# ['Sports']
#
#
# Adi face ki kuda use cheyocha akka
# ['Politics']
#
#
# Adi gadi ki akkada punches veyalo telidhu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi gadu endi paina pataram lonalotaram dance chestunnadu
# ['Sports']
#
#
# Adi gandi ram prasad gandi chala over action nakodukulu
# ['Sports']
#
#
# Adi gari punchulaki chala baga enjoy cheysthunamu super bro mee punchulu
# ['Sports']
#
#
# Adi garu miru koncham thaginchu kunte manchi chilar ga cheyakandi Ok
# ['Politics']
#
#
# Adi garu today promo gurinchi video cheyyledu why
# ['Politics']
#
#
# Adi jagathi iche respect devayani ki atta lekepoina andaru kalisi undalani
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi lanza aa ancour kuda peda lanza adi chapay sollu meru vini malli maku yandhuku e karma
# ['Sports']
#
#
# Adi life gurinchi baga chupincharu
# ['Sports']
#
#
# Adi madata mancham kadu navvaru mancham talli
# ['Sports']
#
#
# Adi may be secret task anukunta
# ['Politics']
#
#
# Adi movie release ayyaka direct ga video song chusthe telusthundi le
# ['Politics']
#
#
# Adi natakam donga mohamdhi asti anta rapinchukoni seetha vallani bhayatiki pampinchadaniki
# ['Sports']
#
#
# Adi ni lanti manushulu inka vunnara
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi nilanti vallaki but feelings unnavallaki oka great movie
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi nora leka pothe kakkus dodde
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi oka ata adukunadu andarini super anna priya ki thanks cheppu niku baga support chesindee
# ['Politics']
#
#
# adi oka mental meru show valu trp kosam mato adukuntunaro eandam gola edi
# ['Sports']
#
#
# Adi oka Story ra chiraku dobbedhi sodhi serials
# ['Sports']
#
#
# Adi over acting Challa Chesatunadu he is a entertainer good but Over acting Chekara babu
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi over action chudalekapothu unnamu
# ['Sports']
#
#
# Adi question haa pillalu ela pudutharu anedi
# ['Politics']
#
#
# Adi reddy garu inka video raledu
# ['Politics']
#
#
# Adi reddy garu soheal big boss first nunnchi agressive
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi reddy ji bigg boss aipotondi kadha next ye videos plan chestunav
# ['Sports']
#
#
# Adi Reddy meeru cheppagaane Anni aipov
# ['Sports']
#
#
# Adi reddy u must do a video on sohel mehaboob cheating bigboss
# ['Politics']
#
#
# adi sagadeyadaniki kuda wst directr ankitha old char bagnde and abhi kuda wst dirctn chetha serial
# ['Politics']
#
#
# Adi shantiki tyaganiki sanketam
# ['Sports']
#
#
# Adi skin lo absorb ipothunda leda wash chesukovala
# ['Politics']
#
#
# Adi sudiranna py panchulesthey puchha paguluddi
# ['Sports']
#
#
# Adi task start kaka mundu thinnadu anthe
# ['Sports']
#
#
# Adi telugus attitude miru ye tv channel lo chudandi debate pedithe okaru maatlade daka aagaru
# ['Sports']
#
#
# Adi u r so great neeku help chesinaa abhi nee inkaa gurtu pettukoni
# ['Politics']
#
#
# Adi unte bagundedi chala bagundi mve
# ['Sports']
#
#
# Adi valley Mana desam Ila mg poyinde Inka pothundi kuda
# ['Sports']
#
#
# Adi vaste first radiation tagipotundi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi vro mottam nashnam chesindannavallu like cheyandi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adi vunte e patti yaparam endku chestadu em chese leka sollu chppkuntdu
# ['Sports']
#
#
# adigindaniki answer cheppaledu
# ['Politics']
#
#
# Adigithe thappu yemiti vadu chesindi ade kada pulihora kalapa Leda memu chudaleda
# ['Politics']
#
#
# Adiki comedy movies review bbaga cheputhadu
# ['Sports']
#
#
# Adina social experiment prank cheyyandi
# ['Entertainment (movies,serials,webseries)']
#
#
# Adini koncham reaction taginchuko manadi
# ['Politics']
#
#
# Adini yavarikanna chupiyandra elage vadhileyakkandira
# ['Sports']
#
#
# Adipinchesaru bro baga but super film
# ['Entertainment (movies,serials,webseries)']
#
#
# Adirindi bayya chala baga chesaru
# ['Entertainment (movies,serials,webseries)']
#
#
# Aditational mice vark avutunda sir
# ['Sports']
#
#
# Adithya apesthadu dani oo pedda trilling scene laa promo okati
# ['Sports']
#
#
# Adithya devatha serial lo valu raledha akka
# ['Entertainment (movies,serials,webseries)']
#
#
# Aditya anna hindi nechukoka povadame manchindhi oka vela nerchukunte fun pothadhi manohar anna
# ['Sports']
#
#
# Aditya Anna nv ilage matladu majja ga vundhi
# ['Sports']
#
#
# aditya joshi gudaludadisi kotali
# ['Sports']
#
#
# Aditya ki sathya ki marraige chestharu anevallu oka like
# ['Politics']
#
#
# Aditya kuda elane anukunte karthikadepam avthundi
# ['Sports']
#
#
# Aditya only belongs to rukku Satya ki Edo Oka mugimpu ivvandi
# ['Entertainment (movies,serials,webseries)']
#
#
# Aditya rukmini tondaraga kaluvali valla pair chala baguntadi
# ['Sports']
#
#
# Aditya satya jodi super vallake pair bagundi rukku aditya ki suit avvalwdu
# ['Entertainment (movies,serials,webseries)']
#
#
# Aditya satya ku saport ga vundali veriddariki marriage avvali i like doth of you
# ['Entertainment (movies,serials,webseries)']
#
#
# Aditya Vikram Birla gurinchi oka video cheyyandi
# ['Sports']
#
#
# Adivi pandi polam lo hadavudi chesinattundi
# ['Sports']
#
#
# Adiyana mein performance super
# ['Sports']
#
#
# Administrarion ki rowdiisim ki tedha telusukondi jai cbn
# ['Entertainment (movies,serials,webseries)']
#
#
# Adni alavodileyakandira Babu evadikaina chupinchandra
# ['Sports']
#
#
# Ado oka instresting meter vundyvuntadi
# ['Sports']
#
#
# Ado teliyani magic chesaru bro
# ['Sports']
#
#
# adobe premiere gurimchi cheppandi
# ['Sports']
#
#
# Adsense account ki enni channels add chayavachu
# ['Sports']
#
#
# Adsense ki ma adras marindhi bro ala chepandi pless
# ['Politics']
#
#
# AdSense lo URL yem enter cheyali bro
# ['Sports']
#
#
# Adsense manaki monitization avvakamunde chesukovacha
# ['Sports']
#
#
# Adu avadu bahu bali tho polusthunnadu
# ['Sports']
#
#
# Adugaduguna addupaduthunna stupid anchor
# ['Sports']
#
#
# Adult movies ekkuva ayyayi e madhya industry la
# ['Entertainment (movies,serials,webseries)']
#
#
# Adyna dabbu unte aa enjoyment veru
# ['Sports']
#
#
# Ae serial lo chusina ede vishwasam movie bgm emo prati emotion ki ide bgm
# ['Sports']
#
#
# Aegte onion hair oil review cheyandi sis
# ['Entertainment (movies,serials,webseries)']
#
#
# Aekkada tesukunnaru ee dresses online lona
# ['Entertainment (movies,serials,webseries)']
